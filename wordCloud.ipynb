# %% [markdown]
# # 词云图

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse100.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)

# %%
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
wordDict
# Out:
# {'擦': 0.010569589234480264,
#  '国务院': 0.009840356676614002,
#  '岩石': 0.016131532594764998,
#  '庆典': 0.00841361104665195,
#  '有形': 0.004889385031583005,
#  '冶金': 0.008972639608062149,
#  '彬': 0.020479989800232804,
#  '市售': 0.003789004609515662,
#  '探究': 0.00995350489436721,
#  '工程图': 0.0073009695272371255,
#  '药物': 0.016474981251434748,
#  '稻作': 0.005724637318491053,
#  '楼阁': 0.012192262141784253,
#  '散客': 0.003764255437476061,
#  '上进心': 0.008843477701026212,
#  '北': 0.011461596506606657,
#  '理想化': 0.007873775224492759,
#  '自由主义': 0.02703669676827067,
#  '组成部分': 0.005537551707255937,
#  '款项': 0.019666903710117416,
#  '学科知识': 0.025412096169067682,
#  '智能化': 0.01470432262033213,
#  '程度': 0.009775659456906232,
#  '水流': 0.012814127960099127,
#  '承包人': 0.011217935226825458,
#  'for': 0.01731718865857237,
#  '邮件': 0.009495648935682423,
#  '软件程序': 0.013513942329114266,
#  '先为': 0.0009697923195258021,
#  '总管': 0.01734388715783407,
#  '各期': 0.0016423361714896932,
#  '关键性': 0.007461188373493438,
#  '马云': 0.002948272481357944,
#  '增值税': 0.010296434920193632,
#  '特定': 0.010504088768982343,
#  '病变': 0.025325239088590665,
#  '菠萝': 0.007686146751180879,
#  '上开': 0.0012897169995095756,
#  '左侧': 0.009242182778229078,
#  '报检': 0.005104098096549841,
#  '评审': 0.006169207132253806,
#  '无色': 0.005762932229797765,
#  '表达式': 0.01975042897482781,
#  '中前': 0.004475358445353033,
#  '停业': 0.0029241415256780747,
#  '电压': 0.011186288720074607,
#  '华人': 0.008497461848783224,
#  '艺术修养': 0.006373992332041729,
#  '有机物': 0.021327379643190342,
#  '谷仓': 0.004698585461304738,
#  '电磁波': 0.007380385103960961,
#  '特质': 0.011295785392772472,
#  '设计': 0.012563402580596461,
#  '计税': 0.0017790402356056138,
#  '居留': 0.003356124960110674,
#  '明确分工': 0.0055437055614068744,
#  '卡尔': 0.024921481499306484,
#  '形体': 0.009399550706197217,
#  '附表': 0.005933867567872745,
#  '共享': 0.006428153270901923,
#  '精通': 0.006155386486020622,
#  '阶段性': 0.0113958820233073,
#  '刘兵': 0.003599458882241864,
#  '液压泵': 0.009010771091628851,
#  '溪': 0.009827750380767424,
#  '替代性': 0.0037404440817162977,
#  '钢丝绳': 0.0069698034520797895,
#  '二十一': 0.010641521565708707,
#  '西门子': 0.002568263416458179,
#  '飞行器': 0.010434414397730752,
#  '苏轼': 0.008918254244951506,
#  '能耗': 0.005626968924149914,
#  '炼油厂': 0.00524521789916485,
#  '综合治理': 0.010116639449358571,
#  '茯苓': 0.009788595943814035,
#  '曹丕': 0.008042292939951975,
#  '投机': 0.004272645862808584,
#  '注疏': 0.012670872940683496,
#  '从以': 0.0020752511031034947,
#  '元朝': 0.013168055181818883,
#  '植株': 0.018545058343809647,
#  '广东省': 0.009215369234953537,
#  '谓': 0.022538052679502988,
#  '原定': 0.005991103461666566,
#  '商贸': 0.010330703709347262,
#  '船只': 0.012980184724635614,
#  '市场': 0.014097750065129974,
#  '最低': 0.00678196916151197,
#  '理论体系': 0.006406472064050318,
#  '勇于创新': 0.009977565300522896,
#  '明月': 0.012687373543135256,
#  '防潮': 0.007860196480218483,
#  '丹青': 0.009334252177522817,
#  '圈层': 0.004490282029649134,
#  '出版': 0.021009666457187513,
#  '李涛': 0.017857536712401888,
#  '牛奶': 0.014114967207511335,
#  '等作': 0.0017836329089116415,
#  '反应器': 0.010681100383412336,
#  '不安': 0.016299973841415575}

# %%
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse150.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse200.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse250.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse300.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse350.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse400.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse450.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse450.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
