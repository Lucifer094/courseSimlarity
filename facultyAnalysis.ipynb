# %% [markdown]
# # 院系相似度处理

# %% [markdown]
# ### 1.热力图可视化计算机院

# %% [markdown]
# #### （1）KMeans

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\Kmeans\similarityFaculty.csv'
facultySimDF=pd.read_csv(sourcePath, encoding='utf-8', index_col=0, header=0)

# %%
similarityCSDF=facultySimDF.iloc[0:11,0:11]
similarityCSDF.describe()
# Out:
#        西南石油大学 计算机科学与技术  安徽大学 计算机科学与技术  潍坊学院 计算机科学与技术  曲阜师范大学 计算机科学与技术  \
# count        11.000000      11.000000      11.000000        11.000000
# mean          0.970758       0.971065       0.972750         0.971202
# std           0.010920       0.010771       0.009863         0.011040
# min           0.958953       0.958869       0.962779         0.958978
# 25%           0.964720       0.965362       0.968580         0.965273
# 50%           0.970583       0.970650       0.971808         0.970618
# 75%           0.971605       0.971555       0.973786         0.974318
# max           1.000000       1.000000       1.000000         1.000000
#
#        湖北理工学院 计算机科学与技术  广州大学 计算机科学与技术  广东海洋大学 计算机科学与技术  哈尔滨工程大学 计算机科学与技术  \
# count        11.000000      11.000000        11.000000         11.000000
# mean          0.963632       0.967361         0.971510          0.963106
# std           0.012244       0.011307         0.010799          0.012328
# ...

# %%
similarityDifDF=facultySimDF.iloc[0:11,11:]
similarityDifDF.describe()
# Out:
#        广东海洋大学 汉语国际教育  广东海洋大学 物联网工程  广东海洋大学 轮机工程  广东海洋大学 工业工程  广东海洋大学 能源与动力工程  \
# count      11.000000     11.000000    11.000000    11.000000       11.000000
# mean        0.952518      0.966508     0.951324     0.962756        0.955780
# std         0.009616      0.005966     0.008324     0.006746        0.008946
# min         0.933781      0.957961     0.936618     0.949987        0.940433
# 25%         0.947397      0.963256     0.944522     0.959193        0.950014
# 50%         0.955181      0.965510     0.956034     0.966397        0.960487
# 75%         0.957976      0.971188     0.956875     0.967393        0.962410
# max         0.964855      0.977089     0.960709     0.969637        0.967244
#
#        广东海洋大学 政治学与行政学  广东海洋大学 农业资源与环境  广东海洋大学 食品科学与工程  广东海洋大学 土地资源管理  \
# count       11.000000       11.000000       11.000000      11.000000
# mean         0.955581        0.946337        0.946918       0.956586
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set(font='STSong')  # 解决中文字体显示
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(similarityCSDF, annot=True, linewidths=.5, ax=ax, cmap="vlag")
# plt.show()

# %% [markdown]
# #### （2）TF-IDF

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\Tf-Idf\similarityFaculty.csv'
facultySimDF=pd.read_csv(sourcePath, encoding='utf-8', index_col=0, header=0)

# %%
similarityCSDF=facultySimDF.iloc[0:11,0:11]
similarityCSDF.describe()
# Out:
#        西南石油大学 计算机科学与技术  安徽大学 计算机科学与技术  潍坊学院 计算机科学与技术  曲阜师范大学 计算机科学与技术  \
# count        11.000000      11.000000      11.000000        11.000000
# mean          0.513265       0.498940       0.532923         0.509587
# std           0.167304       0.171616       0.162903         0.168023
# min           0.356465       0.366742       0.360476         0.376593
# 25%           0.452265       0.429229       0.475027         0.450115
# 50%           0.466977       0.447175       0.503657         0.461106
# 75%           0.505479       0.491836       0.521338         0.500644
# max           1.000000       1.000000       1.000000         1.000000
#
#        湖北理工学院 计算机科学与技术  广州大学 计算机科学与技术  广东海洋大学 计算机科学与技术  哈尔滨工程大学 计算机科学与技术  \
# count        11.000000      11.000000        11.000000         11.000000
# mean          0.490340       0.502442         0.511757          0.503592
# std           0.178125       0.169713         0.165378          0.168363
# ...

# %%
similarityDifDF=facultySimDF.iloc[0:11,11:]
similarityDifDF.describe()
# Out:
#        广东海洋大学 汉语国际教育  广东海洋大学 物联网工程  广东海洋大学 轮机工程  广东海洋大学 工业工程  广东海洋大学 能源与动力工程  \
# count      11.000000     11.000000    11.000000    11.000000       11.000000
# mean        0.288324      0.433845     0.336515     0.381398        0.346180
# std         0.072857      0.091712     0.066691     0.069907        0.069076
# min         0.211231      0.351001     0.266941     0.325206        0.280938
# 25%         0.252189      0.374359     0.292048     0.336013        0.294401
# 50%         0.259978      0.416850     0.324848     0.364017        0.334958
# 75%         0.300559      0.445917     0.361405     0.387441        0.364514
# max         0.487176      0.678901     0.499384     0.568436        0.516674
#
#        广东海洋大学 政治学与行政学  广东海洋大学 农业资源与环境  广东海洋大学 食品科学与工程  广东海洋大学 土地资源管理  \
# count       11.000000       11.000000       11.000000      11.000000
# mean         0.290661        0.312401        0.310925       0.315114
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set(font='STSong')  # 解决中文字体显示
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(similarityCSDF, annot=True, linewidths=.5, ax=ax, cmap="vlag")

# %% [markdown]
# #### （3）K-Medoids

# %%
import pandas as pd
sourcePath=r'C:\Users\king\Desktop\king\Course\Course\data\KMedoids\similarityFaculty150.csv'
facultySimDF=pd.read_csv(sourcePath, encoding='utf-8', index_col=0, header=0)

# %%
similarityCSDF=facultySimDF.iloc[0:11,0:11]
similarityCSDF.describe()
# Out:
#        安徽大学 计算机科学与技术  湖北理工学院 计算机科学与技术  潍坊学院 计算机科学与技术  西南大学 计算机科学与技术  \
# count      11.000000        11.000000      11.000000      11.000000
# mean        0.943820         0.929596       0.944708       0.945028
# std         0.020986         0.023568       0.020466       0.021386
# min         0.919713         0.915701       0.921398       0.917238
# 25%         0.932070         0.922076       0.935236       0.936412
# 50%         0.943754         0.923094       0.944491       0.945430
# 75%         0.945987         0.925680       0.947741       0.950029
# max         1.000000         1.000000       1.000000       1.000000
#
#        广东海洋大学 计算机科学与技术  沈阳工业大学 计算机科学与技术  广州大学 计算机科学与技术  哈尔滨工程大学 计算机科学与技术  \
# count        11.000000        11.000000      11.000000         11.000000
# mean          0.943940         0.938807       0.936122          0.926025
# std           0.021301         0.021786       0.021789          0.024594
# ...

# %%
similarityDifDF=facultySimDF.iloc[0:11,11:]
similarityDifDF.describe()
# Out:
#        广东海洋大学 秘书学  广东海洋大学 轮机工程（陆上）  广东海洋大学 物联网工程  广东海洋大学 土地资源管理  \
# count   11.000000        11.000000     11.000000      11.000000
# mean     0.916696         0.907813      0.935412       0.919896
# std      0.013727         0.014965      0.011595       0.016185
# min      0.893128         0.878873      0.915633       0.889010
# 25%      0.907916         0.897099      0.928347       0.910347
# 50%      0.915874         0.914390      0.936631       0.926355
# 75%      0.928504         0.920008      0.943504       0.931875
# max      0.935191         0.923040      0.955454       0.939370
#
#        广东海洋大学 船舶与海洋工程  广东海洋大学 汉语言文学  广东海洋大学 政治学与行政学  广东海洋大学 建筑环境与能源应用工程  \
# count       11.000000     11.000000       11.000000           11.000000
# mean         0.908040      0.909030        0.916241            0.910484
# std          0.013681      0.017074        0.015216            0.015578
# min          0.885941      0.877864        0.889351            0.879843
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set(font='STSong')  # 解决中文字体显示
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(similarityCSDF, annot=True, linewidths=.5, ax=ax, cmap="vlag")

# %% [markdown]
# #### （4）Tencent

# %%
import pandas as pd
sourcePath=r'C:\Users\king\Desktop\king\Course\Course\data\tencent\similarityFaculty.csv'
facultySimDF=pd.read_csv(sourcePath, encoding='utf-8', index_col=0, header=0)

# %%
similarityCSDF=facultySimDF.iloc[0:11,0:11]
similarityCSDF.describe()
# Out:
#        安徽大学 计算机科学与技术  沈阳工业大学 计算机科学与技术  西南大学 计算机科学与技术  广州大学 计算机科学与技术  \
# count      11.000000        11.000000      11.000000      11.000000
# mean        0.730200         0.731646       0.737413       0.725064
# std         0.091018         0.089626       0.088490       0.091710
# min         0.681001         0.688122       0.686432       0.688180
# 25%         0.688166         0.697993       0.701076       0.689744
# 50%         0.709578         0.706541       0.710837       0.698041
# 75%         0.717323         0.714698       0.725372       0.702208
# max         1.000000         1.000000       1.000000       1.000000
#
#        湖北理工学院 计算机科学与技术  西南石油大学 计算机科学与技术  上海师范大学 计算机科学与技术  哈尔滨工程大学 计算机科学与技术  \
# count        11.000000        11.000000        11.000000         11.000000
# mean          0.716881         0.731076         0.719618          0.718703
# std           0.094138         0.090739         0.093358          0.093422
# ...

# %%
similarityDifDF=facultySimDF.iloc[0:11,11:]
similarityDifDF.describe()
# Out:
#        广东海洋大学 建筑环境与能源应用工程  广东海洋大学 海洋资源与环境  广东海洋大学 船舶与海洋工程  广东海洋大学 大气科学  \
# count           11.000000       11.000000       11.000000    11.000000
# mean             0.658486        0.648610        0.658036     0.654580
# std              0.018878        0.017838        0.017902     0.015932
# min              0.631653        0.617567        0.633772     0.633102
# 25%              0.643498        0.635482        0.644445     0.641395
# 50%              0.658878        0.653516        0.655852     0.655974
# 75%              0.671602        0.657097        0.669879     0.663652
# max              0.692725        0.672812        0.691406     0.684451
#
#        广东海洋大学 秘书学  广东海洋大学 植物保护  广东海洋大学 汉语言文学  广东海洋大学 生物工程  广东海洋大学 海洋科学（海洋地质）  \
# count   11.000000    11.000000     11.000000    11.000000          11.000000
# mean     0.645071     0.648315      0.634641     0.634764           0.652458
# std      0.014564     0.016592      0.013688     0.015899           0.018847
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set(font='STSong')  # 解决中文字体显示
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(similarityCSDF, annot=True, linewidths=.5, ax=ax, cmap="vlag")

# %% [markdown]
# #### （5）NKMD

# %%
import pandas as pd
sourcePath=r'C:\Users\king\Desktop\king\Course\Course\data\NKMedoids\similarityFaculty.csv'
facultySimDF=pd.read_csv(sourcePath, encoding='utf-8', index_col=0, header=0)

# %%
similarityCSDF=facultySimDF.iloc[0:11,0:11]
similarityCSDF.describe()
# Out:
#        曲阜师范大学 计算机科学与技术  西南石油大学 计算机科学与技术  湖北理工学院 计算机科学与技术  西南大学 计算机科学与技术  \
# count        11.000000        11.000000        11.000000      11.000000
# mean          0.953570         0.954828         0.944483       0.954237
# std           0.017316         0.016362         0.018540       0.017724
# min           0.933474         0.936665         0.935562       0.930378
# 25%           0.945153         0.947977         0.937647       0.948268
# 50%           0.952536         0.953879         0.939423       0.954603
# 75%           0.957171         0.955369         0.940799       0.957243
# max           1.000000         1.000000         1.000000       1.000000
#
#        哈尔滨工程大学 计算机科学与技术  安徽大学 计算机科学与技术  广州大学 计算机科学与技术  潍坊学院 计算机科学与技术  \
# count         11.000000      11.000000      11.000000      11.000000
# mean           0.941318       0.952927       0.949936       0.955375
# std            0.019690       0.017268       0.017104       0.015977
# ...

# %%
similarityDifDF=facultySimDF.iloc[0:11,11:]
similarityDifDF.describe()
# Out:
#        广东海洋大学 园艺  广东海洋大学 机械设计制造及其自动化  广东海洋大学 信息与计算科学  广东海洋大学 汉语国际教育  \
# count  11.000000           11.000000       11.000000      11.000000
# mean    0.930452            0.938562        0.944003       0.932780
# std     0.012813            0.009896        0.010434       0.012781
# min     0.903535            0.922565        0.923331       0.907057
# 25%     0.922475            0.932353        0.940938       0.928344
# 50%     0.938471            0.943410        0.948883       0.934091
# 75%     0.939760            0.946521        0.951197       0.940089
# max     0.942474            0.948474        0.955705       0.950948
#
#        广东海洋大学 农业资源与环境  广东海洋大学 制药工程  广东海洋大学 食品质量与安全  广东海洋大学 海洋科学（海洋地质）  \
# count       11.000000    11.000000       11.000000          11.000000
# mean         0.922933     0.919030        0.925609           0.930351
# std          0.013138     0.012496        0.011984           0.015060
# min          0.899366     0.894240        0.902765           0.900306
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
sns.set(font='STSong')  # 解决中文字体显示
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(similarityCSDF, annot=True, linewidths=.5, ax=ax, cmap="vlag")

# %% [markdown]
# ### 2.离散度衡量

# %% [markdown]
# #### 数据转换为一维数据

# %%
import operator
import numpy as np
from functools import reduce
csAry=similarityCSDF.values.reshape(11*11,1)
differentAry=facultySimDF.iloc[0:11,11:].values.reshape(11*51,1)

# %%
similarityCSAry = similarityCSDF.values
store = []
for i in range(11):
    for j in range(i):
        temp = []
        temp.append(similarityCSAry[i][j])
        store.append(temp)
csNAry = np.array(store)

# %% [markdown]
# #### （1）KMeans

# %%
pd.DataFrame(data=csNAry).describe()
# Out:
#                0
# count  55.000000
# mean    0.965918
# std     0.005519
# min     0.956344
# 25%     0.961043
# 50%     0.965717
# 75%     0.970600
# max     0.975368

# %%
pd.DataFrame(data=differentAry).describe()
# Out:
#                 0
# count  561.000000
# mean     0.953423
# std      0.010108
# min      0.926009
# 25%      0.946621
# 50%      0.954765
# 75%      0.960590
# max      0.982408

# %% [markdown]
# #### （2）TF-IDF

# %%
pd.DataFrame(data=csNAry).describe()
# Out:
#                0
# count  55.000000
# mean    0.451054
# std     0.052655
# min     0.330081
# 25%     0.416408
# 50%     0.458156
# 75%     0.480978
# max     0.544500

# %%
pd.DataFrame(data=differentAry).describe()
# Out:
#                 0
# count  561.000000
# mean     0.326173
# std      0.078303
# min      0.187393
# 25%      0.274263
# 50%      0.304986
# 75%      0.354025
# max      0.731703

# %% [markdown]
# #### (3)K-Medoids

# %%
pd.DataFrame(data=csNAry).describe()
# Out:
#                0
# count  55.000000
# mean    0.933201
# std     0.010861
# min     0.915701
# 25%     0.922981
# 50%     0.933790
# 75%     0.943795
# max     0.951904

# %%
pd.DataFrame(data=differentAry).describe()
# Out:
#                 0
# count  561.000000
# mean     0.914673
# std      0.017867
# min      0.866687
# 25%      0.902787
# 50%      0.917924
# 75%      0.927929
# max      0.967317

# %% [markdown]
# #### (4)Tencent

# %%
pd.DataFrame(data=csNAry).describe()
# Out:
#                0
# count  55.000000
# mean    0.702386
# std     0.015409
# min     0.676350
# 25%     0.690443
# 50%     0.700523
# 75%     0.711989
# max     0.737063

# %%
pd.DataFrame(data=differentAry).describe()
# Out:
#                 0
# count  561.000000
# mean     0.654084
# std      0.024721
# min      0.603540
# 25%      0.636990
# 50%      0.653516
# 75%      0.667208
# max      0.820509

# %% [markdown]
# #### (5)NKMD

# %%
pd.DataFrame(data=csNAry).describe()
# Out:
#                0
# count  55.000000
# mean    0.946229
# std     0.007853
# min     0.930378
# 25%     0.939884
# 50%     0.947518
# 75%     0.952816
# max     0.959010

# %%
pd.DataFrame(data=differentAry).describe()
# Out:
#                 0
# count  561.000000
# mean     0.931622
# std      0.013724
# min      0.893391
# 25%      0.922618
# 50%      0.934626
# 75%      0.941287
# max      0.972006

# %% [markdown]
# ### 3.相似课程排名

# %% [markdown]
# ##### 大学计算机院系相似度词典

# %%
computerDic={}
for pos1 in range(len(similarityCSDF.index)):
    for pos2 in range(pos1+1,len(similarityCSDF.columns)):
        key = similarityCSDF.index[pos1] + ' ' + similarityCSDF.columns[pos2]
        computerDic[key] = similarityCSDF.iloc[pos1][pos2]
computerDicSor = sorted(computerDic.items(),key=lambda computerDic:computerDic[1],reverse=True)

# %% [markdown]
# ##### 大学计算机院系和其他院系间的相似度词典

# %%
otherDic={}
for pos1 in range(len(similarityDifDF.index)):
    for pos2 in range(len(similarityDifDF.columns)):
        key = similarityDifDF.index[pos1] + ' ' + similarityDifDF.columns[pos2]
        otherDic[key] = similarityDifDF.iloc[pos1][pos2]
otherDicSor = sorted(otherDic.items(),key=lambda otherDic:otherDic[1],reverse=True)

# %% [markdown]
# #### (1)KMeans

# %%
import pandas as pd
computerKMDF = pd.DataFrame(computerDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/Kmeans/facultyCmpSimSor.csv"
computerKMDF.to_csv(storePath, encoding='utf-8', index=False, header=False)

# %%
otherKMDF = pd.DataFrame(otherDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/Kmeans/facultyOtherSimSor.csv"
otherKMDF.to_csv(storePath, encoding='utf-8', index=False, header=False)

# %% [markdown]
# #### (2)TF-IDF

# %%
import pandas as pd
computerTIDF = pd.DataFrame(computerDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/Tf-Idf/facultyCmpSimSor.csv"
computerTIDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %%
otherTIDF = pd.DataFrame(otherDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/Tf-Idf/facultyOtherSimSor.csv"
otherTIDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %% [markdown]
# #### (3)K-Medoids

# %%
import pandas as pd
computerKMDDF = pd.DataFrame(computerDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/KMedoids/facultyCmpSimSor.csv"
computerKMDDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %%
otherKMDDF = pd.DataFrame(otherDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/KMedoids/facultyOtherSimSor.csv"
otherKMDDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %% [markdown]
# #### (4)Tencent

# %%
import pandas as pd
computerTENDF = pd.DataFrame(computerDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/tencent/facultyCmpSimSor.csv"
computerTENDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %%
otherTENDF = pd.DataFrame(otherDicSor)
storePath = "C:/Users/king/Desktop/king/Course/Course/data/tencent/facultyOtherSimSor.csv"
otherTENDF.to_csv(storePath, encoding='ansi', index=False, header=False)

# %% [markdown]
# ##### 4.新的聚类算法，计算评价系数

# %%
import numpy as np
import math
class S_Dbw():
    def __init__(self, data, data_cluster, centers_index):
        """
        data --> raw data
        data_cluster --> The category to which each point belongs(category starts at 0)
        centers_index --> Cluster center index
        """
        self.data = data
        self.data_cluster = data_cluster
        self.centers_index = centers_index
        self.k = len(centers_index)
        # Initialize stdev
        self.stdev = 0
        for i in range(self.k):
            std_matrix_i = np.std(data[self.data_cluster == i], axis=0)
            self.stdev += math.sqrt(np.dot(std_matrix_i.T, std_matrix_i))
        self.stdev = math.sqrt(self.stdev) / self.k
    def density(self, density_list=[]):
        """
        compute the density of one or two cluster(depend on density_list)
        """
        density = 0
        centers_index1 = self.centers_index[density_list[0]]
        if len(density_list) == 2:
            centers_index2 = self.centers_index[density_list[1]]
            center_v = (self.data[centers_index1] + self.data[centers_index2]) / 2
        else:
            center_v = self.data[centers_index1]
        for i in density_list:
            temp = self.data[self.data_cluster == i]
            for j in temp:
                if np.linalg.norm(j - center_v) <= self.stdev:
                    density += 1
        return density
    def Dens_bw(self):
        density_list = []
        result = 0
        for i in range(self.k):
            density_list.append(self.density(density_list=[i]))
        for i in range(self.k):
            for j in range(self.k):
                if i == j:
                    continue
                result += self.density([i, j]) / max(density_list[i], density_list[j])
        return result / (self.k * (self.k - 1))
    def Scat(self):
        theta_s = np.std(self.data, axis=0)
        theta_s_2norm = math.sqrt(np.dot(theta_s.T, theta_s))
        sum_theta_2norm = 0
        for i in range(self.k):
            matrix_data_i = self.data[self.data_cluster == i]
            theta_i = np.std(matrix_data_i, axis=0)
            sum_theta_2norm += math.sqrt(np.dot(theta_i.T, theta_i))
        return sum_theta_2norm / (theta_s_2norm * self.k)
    def S_Dbw_result(self):
        """
        compute the final result
        """
        return self.Dens_bw() + self.Scat()

# %% [markdown]
# #### 500中心

# %%
import pandas as pd
import csv
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\tencent\vectorsNorm.csv'
wordsVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=False)
wordsVectorsArray = wordsVectorsDF.values
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\KMedoids\centers500.csv'
centersVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\KMedoids\labels500.csv'
wordsLablesDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsLables = []
for word in wordsLablesDF.index:
    wordsLables.append(wordsLablesDF.loc[word, 1])
wordsLablesArray = np.array(wordsLables)
sourcePath = r'D:\GitHub\Course\data\tencent\dfIndex.csv'
file = csv.reader(open(sourcePath, 'r', encoding='utf-8'))
wordsUseful = []
for line in file:
    for word in line:
        wordsUseful.append(word)
centersPos = []
for word in centersVectorsDF.index:
    centersPos.append(wordsUseful.index(word))
centersPosArray = np.array(centersPos)

# %%
a = S_Dbw(wordsVectorsArray, wordsLablesArray, centersPosArray)
print(a.S_Dbw_result())
# Out:
# 0.8279110054480189

# %%
import pandas as pd
import csv
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\tencent\vectorsNorm.csv'
wordsVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=False)
wordsVectorsArray = wordsVectorsDF.values
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\NKMedoids\centersLables.csv'
centersPosDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
centersPosArray = centersPosDF.values.T[0].astype(int)
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\NKMedoids\wordsLables.csv'
wordsLablesDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsLablesArray = wordsLablesDF.values.T[0].astype(int)

# %%
a = S_Dbw(wordsVectorsArray, wordsLablesArray, centersPosArray)
print(a.S_Dbw_result())
# Out:
# 0.8000303651046168

# %% [markdown]
# #### 150中心

# %%
import pandas as pd
import csv
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\tencent\vectorsNorm.csv'
wordsVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=False)
wordsVectorsArray = wordsVectorsDF.values
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\KMedoids\centers150.csv'
centersVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\KMedoids\labels150.csv'
wordsLablesDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsLables = []
for word in wordsLablesDF.index:
    wordsLables.append(wordsLablesDF.loc[word, 1])
wordsLablesArray = np.array(wordsLables)
sourcePath = r'D:\GitHub\Course\data\tencent\dfIndex.csv'
file = csv.reader(open(sourcePath, 'r', encoding='utf-8'))
wordsUseful = []
for line in file:
    for word in line:
        wordsUseful.append(word)
centersPos = []
for word in centersVectorsDF.index:
    centersPos.append(wordsUseful.index(word))
centersPosArray = np.array(centersPos)

# %%
a = S_Dbw(wordsVectorsArray, wordsLablesArray, centersPosArray)
print(a.S_Dbw_result())
# Out:
# 0.8786139631932843

# %%
import pandas as pd
import csv
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\tencent\vectorsNorm.csv'
wordsVectorsDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=False)
wordsVectorsArray = wordsVectorsDF.values
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\NKMedoids\centersLables.csv'
centersPosDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
centersPosArray = centersPosDF.values.T[0].astype(int)
sourcePath = r'C:\Users\king\Desktop\king\Course\Course\data\NKMedoids\wordsLables.csv'
wordsLablesDF = pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsLablesArray = wordsLablesDF.values.T[0].astype(int)

# %%
a = S_Dbw(wordsVectorsArray, wordsLablesArray, centersPosArray)
print(a.S_Dbw_result())
# Out:
# 0.863267891643456

# %% [markdown]
# # 词云图展示

# %% [markdown]
# ## 1.K-Medoids

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse150.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse200.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
for word in wordsPD.index:
    wordDict[word] = float(wordsPD.loc[word,1]/wordsPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %% [markdown]
# ## 2.NKMD

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\NKMedoids\wordsNewSimSor.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
sourcePath=r'D:\GitHub\Course\data\NKMedoids\centersLables.csv'
centersPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
for word in centersPD.index:
    centersPD.loc[word, 1] = wordsPD.loc[word, 1]
for word in centersPD.index:
    wordDict[word] = float(centersPD.loc[word,1]/centersPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\NKMedoids\wordsNewSimSor500.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordDict={}
sourcePath=r'D:/GitHub/Course/data/NKMedoids/centersLables500.csv'
centersPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
for word in centersPD.index:
    centersPD.loc[word, 1] = wordsPD.loc[word, 1]
for word in centersPD.index:
    wordDict[word] = float(centersPD.loc[word,1]/centersPD.values.sum())
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
from pylab import *
from PIL import Image
import numpy
# 显示中文
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['font.family'] = 'sans-serif'
# 解决负号'-'显示为方块的问题
mpl.rcParams['axes.unicode_minus'] = False
sourcePath=r'D:\GitHub\Course\user\background.jpg'
# 背景图片
image = Image.open(sourcePath)
graph = numpy.array(image)
# 设置字体，背景颜色，字体最大值，背景图片
wc = WordCloud(font_path='simhei.ttf', background_color='Yellow', max_font_size=150, mask=graph)
wc.generate_from_frequencies(wordDict)
image_color = ImageColorGenerator(graph)
plt.imshow(wc)
plt.imshow(wc.recolor(color_func=image_color))
plt.axis('off')
# Out:
# (-0.5, 1023.5, 829.5, -0.5)

# %% [markdown]
# # 度量分析

# %% [markdown]
# # 1.k-mdoids

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse150.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsPD.values.sum()
# Out:
# 39020.335665339706

# %%
import pandas as pd
sourcePath=r'D:\GitHub\Course\data\KMedoids\sse500.csv'
wordsPD=pd.read_csv(sourcePath, encoding='utf-8', header=None, index_col=0)
wordsPD.values.sum()
# Out:
# 36469.00891025526
